# %% [markdown]
# # PCA

# %% [markdown]
# ###First, in EMR do PCA for (Tmin, Tmax) of stations in each area.

# %%
import pandas as pd
import numpy as np
import sklearn as sk
print 'pandas version: ',pd.__version__
print 'numpy version:',np.__version__
print 'sklearn version:',sk.__version__
# Out:
# pandas version:  0.13.1
# numpy version: 1.8.1
# sklearn version: 0.14.1

# %%
import sys
home_dir='/home/ubuntu/UCSD_BigData'
sys.path.append(home_dir+'/utils')
from find_waiting_flow import *
from AWS_keypair_management import *
import pickle
Creds= pickle.load(open('/home/ubuntu/Vault/Creds.pkl','rb'))
print Creds.keys()
print Creds['mrjob'].keys()
pair=Creds['mrjob']
key_id=pair['key_id']
secret_key=pair['secret_key']
ID=pair['ID']
print ID,key_id
# Out:
# ['launcher', 'mrjob']
# ['key_id', 'secret_key', 's3_logs', 'ID', 's3_scratch']
# yuw176 AKIAIARNTVMBKC4UZA3Q

# %%
# %%writefile mr_weather_PCA.py
#import collections
#Codes = collections.defaultdict(lambda: -1,Codes)
import sys
import cPickle
Dict = cPickle.load( open( "stations_with_minmax.pkl", "rb" ) )
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re,pickle,base64,zlib
from sys import stderr
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

def my_pca(X,n):
    pca = PCA(n_components=n, whiten=True)
    pca.fit(X)
    sum1 = 0
    for i in range(n):
        sum1 = sum1 + pca.explained_variance_ratio_[i]
        if sum1 > 0.99:
            break
    return i,pca.components_

class MR_Weather_pca(MRJob):
    def my_mapper1(self, _, line):
        self.increment_counter('MrJob Counters','my_mapper1',1)
        elements=line.split(',')
        if elements[1]=='TMAX' or elements[1]=='TMIN':
            ndays = sum([e!='' for e in elements[3:]])
            measure = 1
            yield (elements[0],elements[2]), (measure,ndays,elements[3:])
            
    def my_reducer1(self, key, measures):
        self.increment_counter('MrJob Counters','my_reducer1',1)
        sum1 = 0; sum2 = 0; min_max = []
        for nmeasure,ndays,measure in measures:
            sum1 = sum1 + nmeasure; sum2 = sum2 + ndays; min_max = min_max + measure
        if sum1 == 2 and sum2>150:
            yield key, (Dict[key[0]],min_max)
            
    def my_mapper2(self, key, measures):
        self.increment_counter('MrJob Counters','my_mapper2',1)
        value = []
        for i in measures[1]:
            if i == '':
                value.append(np.nan)
            else:
                value.append(float(i))
        filled = pd.Series(value);filled = filled.interpolate();filled = filled.fillna(filled.mean())
        yield measures[0], list(filled)
    
    def my_reducer2(self, area, measures):
        self.increment_counter('MrJob Counters','my_reducer2',1)
        data = list(measures)
        data = np.array(data)
        n,eigenvectors = my_pca(data, data.shape[1])
        yield area, (data.shape[0],n)
    def steps(self):
        return [self.mr(mapper=self.my_mapper1, reducer=self.my_reducer1),
                self.mr(mapper=self.my_mapper2,reducer=self.my_reducer2)]
if __name__ == '__main__':
    MR_Weather_pca.run()
# Out:
# Overwriting mr_weather_PCA.py

# %%
local_data='/home/ubuntu/UCSD_BigData/data/weather/ALL.head.csv'
# !python mr_weather_PCA.py $local_data > PCA_counts_local
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/mr_weather_PCA.ubuntu.20140612.061608.222236
# writing to /tmp/mr_weather_PCA.ubuntu.20140612.061608.222236/step-0-mapper_part-00000
# Counters from step 1:
#   MrJob Counters:
#     my_mapper1: 999
# writing to /tmp/mr_weather_PCA.ubuntu.20140612.061608.222236/step-0-mapper-sorted
# > sort /tmp/mr_weather_PCA.ubuntu.20140612.061608.222236/step-0-mapper_part-00000
# writing to /tmp/mr_weather_PCA.ubuntu.20140612.061608.222236/step-0-reducer_part-00000
# Counters from step 1:
#   MrJob Counters:
#     my_mapper1: 999
#     my_reducer1: 123
# writing to /tmp/mr_weather_PCA.ubuntu.20140612.061608.222236/step-1-mapper_part-00000
# Counters from step 2:
#   MrJob Counters:
#     my_mapper2: 104
# writing to /tmp/mr_weather_PCA.ubuntu.20140612.061608.222236/step-1-mapper-sorted
# > sort /tmp/mr_weather_PCA.ubuntu.20140612.061608.222236/step-1-mapper_part-00000
# writing to /tmp/mr_weather_PCA.ubuntu.20140612.061608.222236/step-1-reducer_part-00000
# Counters from step 2:
#   MrJob Counters:
#     my_mapper2: 104
#     my_reducer2: 3
# Moving /tmp/mr_weather_PCA.ubuntu.20140612.061608.222236/step-1-reducer_part-00000 -> /tmp/mr_weather_PCA.ubuntu.20140612.061608.222236/output/part-00000
# Streaming final output from /tmp/mr_weather_PCA.ubuntu.20140612.061608.222236/output
# removing tmp directory /tmp/mr_weather_PCA.ubuntu.20140612.061608.222236

# %% [markdown]
# First debug on the local dataset. The result is as follows. The function returns each area code and its explanation length for 99%.

# %%
# !cat PCA_counts_local
# Out:
# 158.0	[39, 36]
# 168.0	[20, 17]
# 4.0	[45, 40]

# %%
job_flow_id=find_waiting_flow(key_id,secret_key)
print job_flow_id
#job_flow_id = 'j-2KCJE554SGITB'
# !python mr_weather_PCA.py -r emr --emr-job-flow-id $job_flow_id --file stations_with_minmax.pkl hdfs:/Weather.GHNC/ALL.csv > PCA_results
# Out:
# <boto.emr.emrobject.JobFlow object at 0x3a6fe50> no_script.yoavfreund.20140610.012426.319987 j-QEERH05KMYTO WAITING
# <boto.emr.emrobject.JobFlow object at 0x3a65450> no_script.yoavfreund.20140610.012507.678804 j-NIGXU2E6YEU3 WAITING
# <boto.emr.emrobject.JobFlow object at 0x3a59c50> no_script.yoavfreund.20140610.012515.693483 j-3SOQM885E1GLH WAITING
# <boto.emr.emrobject.JobFlow object at 0x3d76c90> no_script.yoavfreund.20140610.012523.713192 j-34Q4HR41T9BWU WAITING
# <boto.emr.emrobject.JobFlow object at 0x3d90550> no_script.yoavfreund.20140610.012531.672863 j-31PKW9W4C2YQK WAITING
# <boto.emr.emrobject.JobFlow object at 0x3bb8e10> no_script.yoavfreund.20140611.181703.600873 j-2N4U1USC54EM6 WAITING
# <boto.emr.emrobject.JobFlow object at 0x3eabe50> no_script.yoavfreund.20140611.181722.314318 j-3MR2RR5OEXRQ7 WAITING
# <boto.emr.emrobject.JobFlow object at 0x3ec3050> no_script.yoavfreund.20140611.181730.511103 j-2S5LTMBIWD2WB WAITING
# <boto.emr.emrobject.JobFlow object at 0x3ee30d0> no_script.yoavfreund.20140611.181738.864430 j-3TFYHEIHI9VOY WAITING
# j-3TFYHEIHI9VOY
# using configs in /home/ubuntu/.mrjob.conf
# creating new scratch bucket mrjob-5d5e475c8d1b868b
# using s3://mrjob-5d5e475c8d1b868b/tmp/ as our scratch dir on S3
# creating tmp directory /tmp/mr_weather_PCA.ubuntu.20140612.061634.355966
# creating S3 bucket 'mrjob-5d5e475c8d1b868b' to use as scratch space
# Attempting to terminate job...
# Traceback (most recent call last):
#   File "mr_weather_PCA.py", line 62, in <module>
#     MR_Weather_pca.run()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/job.py", line 494, in run
#     mr_job.execute()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/job.py", line 512, in execute
#     super(MRJob, self).execute()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/launch.py", line 147, in execute
#     self.run_job()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/launch.py", line 213, in run_job
#     self.stdout.flush()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/runner.py", line 614, in __exit__
#     self.cleanup()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/emr.py", line 1010, in cleanup
#     super(EMRJobRunner, self).cleanup(mode=mode)
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/runner.py", line 560, in cleanup
#     self._cleanup_job()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/emr.py", line 1084, in _cleanup_job
#     self._opts['ec2_key_pair_file'])
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/ssh.py", line 200, in ssh_terminate_single_job
#     ssh_bin, address, ec2_key_pair_file, ['hadoop', 'job', '-list']))
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/ssh.py", line 82, in ssh_run
#     p = Popen(args, stdout=PIPE, stderr=PIPE, stdin=PIPE)
#   File "/home/ubuntu/anaconda/lib/python2.7/subprocess.py", line 709, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda/lib/python2.7/subprocess.py", line 1326, in _execute_child
#     raise child_exception
# TypeError: execv() arg 2 must contain only strings

# %%
# !head -10 PCA_results
# Out:
# 106.0	[3686, 436]
# 117.0	[3646, 432]
# 120.0	[3641, 475]
# 128.0	[3669, 392]
# 131.0	[3640, 411]
# 139.0	[3684, 441]
# 142.0	[3717, 434]
# 153.0	[3707, 471]
# 16.0	[3663, 387]
# 164.0	[3679, 418]

# %%
length = []; area=[]; k = []
for line in open('PCA_results','r').readlines():
    line=line.replace('[','')
    line=line.replace(']','')
    line=line.replace(',','')
    line=line.split()
    k.append(numpy.int(line[1]))
    length.append(numpy.int(line[2]))
    temp_area = numpy.float(line[0])
    area.append(int(temp_area))
print mean(length)
# Out:
# 428.35546875

# %% [markdown]
# As is shown above, the average explanation length for 99% is ~428.

# %%
D = pd.DataFrame({'area': area, 'length': length, 'k':k})
D.head()
# Out:
#    area     k  length
# 0   106  3686     436
# 1   117  3646     432
# 2   120  3641     475
# 3   128  3669     392
# 4   131  3640     411
#
# [5 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.figure()
D['length'].hist()

# %% [markdown]
# The distribution of description length is more clearly shown in the histogram above.

# %% [markdown]
# ###Second, merge the neighboring nodes to get lower description length.

# %% [markdown]
# First, try one iteration of merging. The area code I use is from 0-255, and neighboring area codes correspond to neighbouring areas on the globe. So the candidates of merging can be expressed as (0,1),(2,3), ... ,(254,255). The new area dictionary is easily obtained:

# %%
import cPickle
Dict = cPickle.load( open( "stations_with_minmax.pkl", "rb" ) )

new_Dict = {}
for i in Dict:
    new_Dict[i] = np.int(np.floor(Dict[i]/2))

# %%
new_Dict
# Out:
# {'ACW00011604': 32,
#  'ACW00011647': 32,
#  'AE000041196': 35,
#  'AF000040930': 58,
#  'AG000060390': 58,
#  'AG000060590': 38,
#  'AG000060611': 35,
#  'AG000060680': 35,
#  'AGE00135039': 58,
#  'AJ000037575': 106,
#  'AJ000037579': 128,
#  'AJ000037605': 128,
#  'AJ000037636': 128,
#  'AJ000037639': 63,
#  'AJ000037656': 128,
#  'AJ000037661': 63,
#  'AJ000037668': 128,
#  'AJ000037673': 128,
#  'AJ000037674': 128,
#  'AJ000037675': 106,
#  'AJ000037679': 128,
#  'AJ000037729': 128,
#  'AJ000037734': 128,
#  'AJ000037735': 63,
#  'AJ000037740': 63,
#  'AJ000037742': 128,
#  'AJ000037744': 63,
#  'AJ000037747': 63,
#  'AJ000037749': 63,
#  'AJ000037753': 63,
#  'AJ000037756': 63,
#  'AJ000037759': 63,
#  'AJ000037769': 63,
#  'AJ000037813': 128,
#  'AJ000037816': 128,
#  'AJ000037825': 128,
#  'AJ000037831': 128,
#  'AJ000037832': 128,
#  'AJ000037835': 128,
#  'AJ000037844': 62,
#  'AJ000037849': 62,
#  'AJ000037850': 128,
#  'AJ000037860': 63,
#  'AJ000037861': 128,
#  'AJ000037866': 63,
#  'AJ000037869': 128,
#  'AJ000037883': 128,
#  'AJ000037888': 128,
#  'AJ000037893': 128,
#  'AJ000037895': 62,
#  'AJ000037898': 128,
#  'AJ000037899': 62,
#  'AJ000037901': 128,
#  'AJ000037902': 128,
#  'AJ000037905': 62,
#  'AJ000037907': 62,
#  'AJ000037912': 128,
#  'AJ000037913': 128,
#  'AJ000037914': 128,
#  'AJ000037922': 128,
#  'AJ000037923': 62,
#  'AJ000037925': 62,
#  'AJ000037936': 62,
#  'AJ000037941': 128,
#  'AJ000037946': 128,
#  'AJ000037947': 59,
#  'AJ000037957': 59,
#  'AJ000037962': 128,
#  'AJ000037968': 128,
#  'AJ000037972': 62,
#  'AJ000037978': 62,
#  'AJ000037981': 128,
#  'AJ000037984': 59,
#  'AJ000037985': 59,
#  'AJ000037989': 59,
#  'ALE00100939': 128,
#  'ALE00108905': 128,
#  'AM000037608': 128,
#  'AM000037609': 128,
#  'AM000037618': 63,
#  'AM000037627': 128,
#  'AM000037629': 128,
#  'AM000037682': 63,
#  'AM000037683': 128,
#  'AM000037686': 63,
#  'AM000037689': 128,
#  'AM000037693': 63,
#  'AM000037694': 128,
#  'AM000037695': 63,
#  'AM000037698': 128,
#  'AM000037699': 63,
#  'AM000037700': 128,
#  'AM000037704': 63,
#  'AM000037705': 128,
#  'AM000037706': 63,
#  'AM000037708': 128,
#  'AM000037711': 63,
#  'AM000037713': 128,
#  'AM000037719': 63,
#  'AM000037772': 128,
#  'AM000037773': 128,
#  'AM000037774': 62,
#  'AM000037781': 63,
#  'AM000037782': 128,
#  'AM000037785': 128,
#  'AM000037786': 128,
#  'AM000037787': 62,
#  'AM000037789': 62,
#  'AM000037791': 62,
#  'AM000037792': 63,
#  'AM000037798': 128,
#  'AM000037801': 62,
#  'AM000037802': 128,
#  'AM000037808': 63,
#  'AM000037815': 62,
#  'AM000037871': 62,
#  'AM000037872': 128,
#  'AM000037873': 128,
#  'AM000037874': 62,
#  'AM000037875': 128,
#  'AM000037876': 128,
#  'AM000037878': 128,
#  'AM000037880': 128,
#  'AM000037884': 128,
#  'AM000037887': 128,
#  'AM000037897': 62,
#  'AM000037954': 128,
#  'AM000037958': 59,
#  'AM000037959': 62,
#  'AO000066160': 34,
#  'AO000066270': 34,
#  'AO000066390': 34,
#  'AO000066410': 34,
#  'AO000066422': 34,
#  'AO000066447': 34,
#  'AQC00914000': 128,
#  'AQC00914005': 128,
#  'AQC00914021': 0,
#  'AQC00914060': 128,
#  'AQC00914135': 128,
#  'AQC00914138': 128,
#  'AQC00914145': 128,
#  'AQC00914149': 128,
#  'AQC00914188': 0,
#  'AQC00914248': 128,
#  'AQC00914397': 0,
#  'AQC00914424': 128,
#  'AQC00914594': 128,
#  'AQC00914650': 128,
#  'AQC00914822': 0,
#  'AQC00914869': 0,
#  'AQC00914873': 0,
#  'AQC00914902': 128,
#  'AQC00914912': 128,
#  'AQW00061705': 0,
#  'AR000000001': 128,
#  'AR000000002': 128,
#  'AR000000003': 128,
#  'AR000000004': 128,
#  'AR000000005': 128,
#  'AR000000006': 128,
#  'AR000000007': 128,
#  'AR000000008': 34,
#  'AR000000009': 128,
#  'AR000000010': 128,
#  'AR000000011': 34,
#  'AR000000012': 128,
#  'AR000000013': 128,
#  'AR000000014': 128,
#  'AR000000015': 128,
#  'AR000000016': 128,
#  'AR000087007': 32,
#  'AR000087065': 32,
#  'AR000087078': 32,
#  'AR000087129': 32,
#  'AR000087155': 32,
#  'AR000087217': 32,
#  'AR000087257': 32,
#  'AR000087270': 32,
#  'AR000087344': 32,
#  'AR000087374': 32,
#  'AR000087418': 32,
#  'AR000087534': 32,
#  'AR000087623': 32,
#  'AR000087692': 34,
#  'AR000087715': 32,
#  'AR000087803': 32,
#  'AR000087828': 32,
#  'AR000087860': 32,
#  'AR000087925': 32,
#  'AR000870470': 32,
#  'AR000873050': 32,
#  'AR000875440': 32,
#  'AR000875850': 32,
#  'AR000877500': 32,
#  'ASN00001000': 128,
#  'ASN00001001': 128,
#  'ASN00001003': 128,
#  'ASN00001004': 128,
#  'ASN00001005': 44,
#  'ASN00001006': 44,
#  'ASN00001007': 44,
#  'ASN00001008': 128,
#  'ASN00001009': 44,
#  'ASN00001010': 128,
#  'ASN00001011': 128,
#  'ASN00001012': 44,
#  'ASN00001013': 44,
#  'ASN00001014': 128,
#  'ASN00001016': 128,
#  'ASN00001017': 128,
#  'ASN00001018': 44,
#  'ASN00001019': 44,
#  'ASN00001020': 44,
#  'ASN00001021': 44,
#  'ASN00001022': 128,
#  'ASN00001023': 128,
#  'ASN00001024': 128,
#  'ASN00001025': 44,
#  'ASN00001026': 128,
#  'ASN00001027': 128,
#  'ASN00001028': 128,
#  'ASN00001030': 128,
#  'ASN00001031': 128,
#  'ASN00001032': 128,
#  'ASN00001035': 128,
#  'ASN00002000': 128,
#  'ASN00002001': 128,
#  'ASN00002002': 128,
#  'ASN00002003': 128,
#  'ASN00002004': 128,
#  'ASN00002005': 128,
#  'ASN00002006': 128,
#  'ASN00002007': 128,
#  'ASN00002008': 128,
#  'ASN00002009': 128,
#  'ASN00002010': 128,
#  'ASN00002011': 44,
#  'ASN00002012': 44,
#  'ASN00002013': 128,
#  'ASN00002014': 44,
#  'ASN00002015': 128,
#  'ASN00002016': 128,
#  'ASN00002017': 128,
#  'ASN00002018': 128,
#  'ASN00002019': 128,
#  'ASN00002020': 128,
#  'ASN00002021': 128,
#  'ASN00002022': 128,
#  'ASN00002023': 128,
#  'ASN00002024': 128,
#  'ASN00002025': 128,
#  'ASN00002026': 128,
#  'ASN00002027': 128,
#  'ASN00002028': 128,
#  'ASN00002029': 128,
#  'ASN00002030': 128,
#  'ASN00002031': 128,
#  'ASN00002032': 44,
#  'ASN00002033': 128,
#  'ASN00002034': 128,
#  'ASN00002035': 128,
#  'ASN00002036': 128,
#  'ASN00002037': 128,
#  'ASN00002038': 44,
#  'ASN00002039': 128,
#  'ASN00002040': 128,
#  'ASN00002041': 128,
#  'ASN00002042': 128,
#  'ASN00002043': 128,
#  'ASN00002044': 128,
#  'ASN00002046': 128,
#  'ASN00002047': 128,
#  'ASN00002048': 128,
#  'ASN00002049': 128,
#  'ASN00002050': 128,
#  'ASN00002051': 128,
#  'ASN00002052': 128,
#  'ASN00002053': 128,
#  'ASN00002055': 128,
#  'ASN00002056': 44,
#  'ASN00002057': 128,
#  'ASN00002058': 128,
#  'ASN00002059': 128,
#  'ASN00002060': 128,
#  'ASN00002061': 128,
#  'ASN00002062': 128,
#  'ASN00002063': 128,
#  'ASN00002064': 44,
#  'ASN00002065': 128,
#  'ASN00002066': 128,
#  'ASN00002067': 128,
#  'ASN00002069': 128,
#  'ASN00002070': 128,
#  'ASN00002071': 44,
#  'ASN00002075': 128,
#  'ASN00003000': 128,
#  'ASN00003001': 128,
#  'ASN00003002': 44,
#  'ASN00003003': 44,
#  'ASN00003004': 44,
#  'ASN00003005': 128,
#  'ASN00003006': 44,
#  'ASN00003007': 44,
#  'ASN00003008': 128,
#  'ASN00003009': 128,
#  'ASN00003010': 128,
#  'ASN00003011': 128,
#  'ASN00003012': 128,
#  'ASN00003013': 128,
#  'ASN00003014': 128,
#  'ASN00003015': 128,
#  'ASN00003016': 128,
#  'ASN00003017': 128,
#  'ASN00003018': 128,
#  'ASN00003019': 128,
#  'ASN00003020': 128,
#  'ASN00003021': 128,
#  'ASN00003022': 128,
#  'ASN00003023': 128,
#  'ASN00003024': 128,
#  'ASN00003025': 44,
#  'ASN00003026': 128,
#  'ASN00003027': 128,
#  'ASN00003028': 128,
#  'ASN00003029': 128,
#  'ASN00003030': 44,
#  'ASN00003031': 128,
#  'ASN00003032': 44,
#  'ASN00003033': 128,
#  'ASN00003035': 128,
#  'ASN00003036': 128,
#  'ASN00003037': 128,
#  'ASN00003039': 128,
#  'ASN00003040': 44,
#  'ASN00003041': 128,
#  'ASN00003042': 44,
#  'ASN00003043': 128,
#  'ASN00003044': 128,
#  'ASN00003045': 128,
#  'ASN00003046': 128,
#  'ASN00003047': 128,
#  'ASN00003048': 128,
#  'ASN00003049': 128,
#  'ASN00003050': 128,
#  'ASN00003051': 44,
#  'ASN00003052': 128,
#  'ASN00003053': 128,
#  'ASN00003054': 128,
#  'ASN00003055': 128,
#  'ASN00003056': 128,
#  'ASN00003057': 44,
#  'ASN00003058': 128,
#  'ASN00003059': 44,
#  'ASN00003060': 128,
#  'ASN00003061': 128,
#  'ASN00003062': 128,
#  'ASN00003063': 128,
#  'ASN00003064': 128,
#  'ASN00003065': 128,
#  'ASN00003066': 128,
#  'ASN00003068': 128,
#  'ASN00003069': 44,
#  'ASN00003072': 128,
#  'ASN00003073': 128,
#  'ASN00003074': 128,
#  'ASN00003075': 128,
#  'ASN00003076': 44,
#  'ASN00003077': 128,
#  'ASN00003078': 44,
#  'ASN00003079': 128,
#  'ASN00003080': 44,
#  'ASN00003081': 128,
#  'ASN00003082': 128,
#  'ASN00003083': 128,
#  'ASN00003084': 128,
#  'ASN00003085': 128,
#  'ASN00003086': 128,
#  'ASN00003087': 128,
#  'ASN00003088': 128,
#  'ASN00003089': 44,
#  'ASN00003090': 128,
#  'ASN00003091': 128,
#  'ASN00003092': 44,
#  'ASN00003093': 44,
#  'ASN00003095': 128,
#  'ASN00003096': 44,
#  'ASN00003098': 128,
#  'ASN00003100': 128,
#  'ASN00003103': 128,
#  'ASN00003104': 128,
#  'ASN00003105': 128,
#  'ASN00004000': 44,
#  'ASN00004001': 128,
#  'ASN00004002': 44,
#  'ASN00004003': 128,
#  'ASN00004004': 128,
#  'ASN00004005': 128,
#  'ASN00004006': 128,
#  'ASN00004007': 128,
#  'ASN00004008': 128,
#  'ASN00004009': 128,
#  'ASN00004010': 128,
#  'ASN00004011': 128,
#  'ASN00004012': 128,
#  'ASN00004013': 128,
#  'ASN00004014': 128,
#  'ASN00004015': 128,
#  'ASN00004016': 128,
#  'ASN00004017': 128,
#  'ASN00004018': 128,
#  'ASN00004019': 44,
#  'ASN00004020': 44,
#  'ASN00004021': 128,
#  'ASN00004022': 128,
#  'ASN00004023': 128,
#  'ASN00004024': 128,
#  'ASN00004025': 128,
#  'ASN00004026': 128,
#  'ASN00004027': 44,
#  'ASN00004028': 44,
#  'ASN00004030': 128,
#  'ASN00004031': 128,
#  'ASN00004032': 44,
#  'ASN00004033': 128,
#  'ASN00004034': 128,
#  'ASN00004035': 44,
#  'ASN00004036': 128,
#  'ASN00004037': 128,
#  'ASN00004038': 128,
#  'ASN00004039': 128,
#  'ASN00004040': 128,
#  'ASN00004041': 128,
#  'ASN00004042': 128,
#  'ASN00004043': 44,
#  'ASN00004044': 128,
#  'ASN00004045': 44,
#  'ASN00004046': 128,
#  'ASN00004047': 128,
#  'ASN00004048': 128,
#  'ASN00004049': 128,
#  'ASN00004050': 128,
#  'ASN00004051': 128,
#  'ASN00004052': 128,
#  'ASN00004053': 128,
#  'ASN00004054': 128,
#  'ASN00004055': 128,
#  'ASN00004056': 128,
#  'ASN00004057': 128,
#  'ASN00004058': 128,
#  'ASN00004059': 128,
#  'ASN00004060': 128,
#  'ASN00004061': 128,
#  'ASN00004062': 128,
#  'ASN00004063': 128,
#  'ASN00004064': 128,
#  'ASN00004065': 128,
#  'ASN00004066': 128,
#  'ASN00004067': 128,
#  'ASN00004068': 128,
#  'ASN00004069': 128,
#  'ASN00004070': 128,
#  'ASN00004071': 128,
#  'ASN00004072': 128,
#  'ASN00004074': 44,
#  'ASN00004076': 128,
#  'ASN00004077': 128,
#  'ASN00004079': 44,
#  'ASN00004080': 128,
#  'ASN00004081': 128,
#  'ASN00004082': 44,
#  'ASN00004083': 44,
#  'ASN00004084': 44,
#  'ASN00004085': 128,
#  'ASN00004086': 128,
#  'ASN00004087': 128,
#  'ASN00004088': 128,
#  'ASN00004089': 128,
#  'ASN00004090': 44,
#  'ASN00004092': 128,
#  'ASN00004093': 128,
#  'ASN00004094': 128,
#  'ASN00004096': 128,
#  'ASN00004097': 44,
#  'ASN00004098': 128,
#  'ASN00004099': 44,
#  'ASN00004101': 128,
#  'ASN00004102': 128,
#  'ASN00004103': 128,
#  'ASN00004104': 44,
#  'ASN00004106': 44,
#  'ASN00005000': 128,
#  'ASN00005001': 128,
#  'ASN00005002': 128,
#  'ASN00005003': 128,
#  'ASN00005004': 128,
#  'ASN00005005': 128,
#  'ASN00005006': 128,
#  'ASN00005007': 44,
#  'ASN00005008': 44,
#  'ASN00005009': 128,
#  'ASN00005010': 128,
#  'ASN00005011': 128,
#  'ASN00005012': 128,
#  'ASN00005013': 128,
#  'ASN00005014': 128,
#  'ASN00005015': 128,
#  'ASN00005016': 44,
#  'ASN00005017': 44,
#  'ASN00005018': 128,
#  'ASN00005019': 128,
#  'ASN00005020': 128,
#  'ASN00005021': 128,
#  'ASN00005022': 128,
#  'ASN00005023': 128,
#  'ASN00005024': 44,
#  'ASN00005025': 128,
#  'ASN00005026': 44,
#  'ASN00005027': 128,
#  'ASN00005028': 128,
#  'ASN00005029': 128,
#  'ASN00005030': 128,
#  'ASN00005031': 128,
#  'ASN00005032': 128,
#  'ASN00005033': 128,
#  'ASN00005034': 128,
#  'ASN00005035': 128,
#  'ASN00005036': 128,
#  'ASN00005037': 128,
#  'ASN00005038': 128,
#  'ASN00005039': 128,
#  'ASN00005040': 128,
#  'ASN00005041': 128,
#  'ASN00005042': 128,
#  'ASN00005043': 128,
#  'ASN00005044': 128,
#  'ASN00005045': 128,
#  'ASN00005046': 128,
#  'ASN00005047': 128,
#  'ASN00005048': 128,
#  'ASN00005049': 128,
#  'ASN00005050': 128,
#  'ASN00005051': 44,
#  'ASN00005052': 128,
#  'ASN00005053': 44,
#  'ASN00005055': 128,
#  'ASN00005057': 128,
#  'ASN00005058': 44,
#  'ASN00005059': 128,
#  'ASN00005060': 44,
#  'ASN00005061': 44,
#  'ASN00005063': 128,
#  'ASN00005064': 44,
#  'ASN00005066': 128,
#  'ASN00005067': 128,
#  'ASN00005068': 128,
#  'ASN00005069': 44,
#  'ASN00005070': 128,
#  'ASN00005071': 128,
#  'ASN00005072': 44,
#  'ASN00005073': 128,
#  'ASN00005074': 128,
#  'ASN00005075': 44,
#  'ASN00005076': 128,
#  'ASN00005078': 128,
#  'ASN00005079': 128,
#  'ASN00005082': 128,
#  'ASN00005083': 128,
#  'ASN00005084': 44,
#  'ASN00005085': 128,
#  'ASN00005086': 128,
#  'ASN00005087': 128,
#  'ASN00005088': 128,
#  'ASN00005089': 128,
#  'ASN00005090': 128,
#  'ASN00005092': 44,
#  'ASN00005093': 128,
#  'ASN00005094': 44,
#  'ASN00005095': 128,
#  'ASN00006000': 128,
#  'ASN00006001': 128,
#  'ASN00006002': 128,
#  'ASN00006003': 128,
#  'ASN00006004': 128,
#  'ASN00006005': 128,
#  'ASN00006006': 128,
#  'ASN00006007': 128,
#  'ASN00006008': 128,
#  'ASN00006009': 128,
#  'ASN00006010': 128,
#  'ASN00006011': 44,
#  'ASN00006012': 128,
#  'ASN00006013': 128,
#  'ASN00006014': 128,
#  'ASN00006015': 128,
#  'ASN00006016': 128,
#  'ASN00006017': 128,
#  'ASN00006018': 128,
#  'ASN00006019': 128,
#  'ASN00006020': 128,
#  'ASN00006021': 128,
#  'ASN00006022': 44,
#  'ASN00006023': 128,
#  'ASN00006024': 128,
#  'ASN00006025': 44,
#  'ASN00006026': 128,
#  'ASN00006027': 128,
#  'ASN00006028': 128,
#  'ASN00006029': 128,
#  'ASN00006030': 128,
#  'ASN00006031': 128,
#  'ASN00006032': 128,
#  'ASN00006033': 128,
#  'ASN00006034': 128,
#  'ASN00006035': 128,
#  'ASN00006036': 128,
#  'ASN00006037': 128,
#  'ASN00006038': 128,
#  'ASN00006039': 128,
#  'ASN00006040': 128,
#  'ASN00006041': 128,
#  'ASN00006042': 128,
#  'ASN00006043': 128,
#  'ASN00006044': 44,
#  'ASN00006045': 128,
#  'ASN00006046': 128,
#  'ASN00006047': 128,
#  'ASN00006048': 128,
#  'ASN00006049': 128,
#  'ASN00006050': 128,
#  'ASN00006051': 128,
#  'ASN00006052': 128,
#  'ASN00006053': 128,
#  'ASN00006054': 128,
#  'ASN00006055': 128,
#  'ASN00006056': 128,
#  'ASN00006057': 128,
#  'ASN00006058': 128,
#  'ASN00006059': 128,
#  'ASN00006060': 128,
#  'ASN00006061': 128,
#  'ASN00006062': 44,
#  'ASN00006063': 128,
#  'ASN00006064': 128,
#  'ASN00006065': 128,
#  'ASN00006066': 128,
#  'ASN00006067': 128,
#  'ASN00006068': 128,
#  'ASN00006069': 128,
#  'ASN00006070': 128,
#  'ASN00006071': 128,
#  'ASN00006072': 44,
#  'ASN00006073': 128,
#  'ASN00006074': 128,
#  'ASN00006075': 128,
#  'ASN00006076': 128,
#  'ASN00006077': 128,
#  'ASN00006078': 128,
#  'ASN00006079': 128,
#  'ASN00006080': 44,
#  'ASN00006081': 128,
#  'ASN00006082': 128,
#  'ASN00006083': 128,
#  'ASN00006084': 128,
#  'ASN00006085': 128,
#  'ASN00006087': 44,
#  'ASN00006088': 128,
#  'ASN00006089': 128,
#  'ASN00006090': 128,
#  'ASN00006091': 128,
#  'ASN00006092': 128,
#  'ASN00006093': 128,
#  'ASN00006094': 44,
#  'ASN00006095': 128,
#  'ASN00006096': 128,
#  'ASN00006097': 128,
#  'ASN00006098': 128,
#  'ASN00006099': 44,
#  'ASN00006100': 128,
#  'ASN00006101': 128,
#  'ASN00006102': 128,
#  'ASN00006103': 128,
#  'ASN00006105': 44,
#  'ASN00006106': 128,
#  'ASN00006107': 128,
#  'ASN00007000': 128,
#  'ASN00007001': 128,
#  'ASN00007002': 128,
#  'ASN00007003': 128,
#  'ASN00007004': 128,
#  'ASN00007005': 128,
#  'ASN00007006': 128,
#  'ASN00007007': 128,
#  'ASN00007008': 128,
#  'ASN00007009': 128,
#  'ASN00007010': 128,
#  'ASN00007011': 128,
#  'ASN00007012': 128,
#  'ASN00007013': 128,
#  'ASN00007014': 128,
#  'ASN00007015': 128,
#  'ASN00007016': 128,
#  'ASN00007017': 44,
#  'ASN00007018': 128,
#  'ASN00007019': 128,
#  'ASN00007020': 128,
#  'ASN00007021': 128,
#  'ASN00007022': 128,
#  'ASN00007023': 128,
#  'ASN00007024': 128,
#  'ASN00007025': 128,
#  'ASN00007026': 128,
#  'ASN00007027': 128,
#  'ASN00007028': 128,
#  'ASN00007029': 128,
#  'ASN00007030': 128,
#  'ASN00007031': 128,
#  'ASN00007032': 128,
#  'ASN00007033': 128,
#  'ASN00007034': 128,
#  'ASN00007035': 128,
#  'ASN00007036': 128,
#  'ASN00007037': 128,
#  'ASN00007038': 128,
#  'ASN00007039': 128,
#  'ASN00007040': 128,
#  'ASN00007041': 128,
#  'ASN00007042': 128,
#  'ASN00007043': 128,
#  'ASN00007044': 128,
#  'ASN00007045': 44,
#  'ASN00007046': 44,
#  'ASN00007047': 128,
#  'ASN00007048': 128,
#  'ASN00007049': 128,
#  'ASN00007050': 128,
#  'ASN00007051': 128,
#  'ASN00007052': 128,
#  'ASN00007053': 128,
#  'ASN00007054': 128,
#  'ASN00007055': 128,
#  'ASN00007056': 128,
#  'ASN00007057': 44,
#  'ASN00007058': 44,
#  'ASN00007059': 128,
#  'ASN00007060': 128,
#  'ASN00007061': 128,
#  'ASN00007062': 44,
#  'ASN00007063': 128,
#  'ASN00007064': 44,
#  'ASN00007065': 128,
#  'ASN00007066': 128,
#  'ASN00007067': 41,
#  'ASN00007068': 128,
#  'ASN00007069': 128,
#  'ASN00007070': 128,
#  'ASN00007071': 128,
#  'ASN00007072': 128,
#  'ASN00007073': 128,
#  'ASN00007074': 128,
#  'ASN00007075': 128,
#  'ASN00007076': 128,
#  'ASN00007077': 128,
#  'ASN00007078': 128,
#  'ASN00007079': 128,
#  'ASN00007080': 44,
#  'ASN00007081': 128,
#  'ASN00007082': 128,
#  'ASN00007083': 128,
#  'ASN00007084': 128,
#  'ASN00007085': 128,
#  'ASN00007086': 128,
#  'ASN00007087': 128,
#  'ASN00007088': 128,
#  'ASN00007089': 128,
#  'ASN00007090': 128,
#  'ASN00007091': 41,
#  'ASN00007092': 128,
#  'ASN00007093': 128,
#  'ASN00007094': 128,
#  'ASN00007095': 128,
#  'ASN00007096': 128,
#  'ASN00007097': 128,
#  'ASN00007098': 128,
#  'ASN00007099': 128,
#  'ASN00007100': 128,
#  'ASN00007101': 128,
#  'ASN00007102': 128,
#  'ASN00007103': 128,
#  'ASN00007104': 128,
#  'ASN00007105': 128,
#  'ASN00007106': 128,
#  'ASN00007107': 128,
#  'ASN00007108': 128,
#  'ASN00007110': 128,
#  'ASN00007111': 128,
#  'ASN00007112': 128,
#  'ASN00007113': 128,
#  'ASN00007114': 128,
#  'ASN00007115': 128,
#  'ASN00007116': 128,
#  'ASN00007117': 128,
#  'ASN00007118': 128,
#  'ASN00007119': 128,
#  'ASN00007120': 128,
#  'ASN00007121': 128,
#  'ASN00007122': 128,
#  'ASN00007123': 128,
#  'ASN00007124': 128,
#  'ASN00007125': 128,
#  'ASN00007126': 128,
#  'ASN00007127': 128,
#  'ASN00007128': 128,
#  'ASN00007129': 128,
#  'ASN00007130': 128,
#  'ASN00007131': 128,
#  'ASN00007132': 128,
#  'ASN00007133': 128,
#  'ASN00007134': 128,
#  'ASN00007135': 128,
#  'ASN00007136': 128,
#  'ASN00007137': 128,
#  'ASN00007139': 41,
#  'ASN00007140': 128,
#  'ASN00007141': 128,
#  'ASN00007142': 128,
#  'ASN00007143': 128,
#  'ASN00007144': 128,
#  'ASN00007145': 128,
#  'ASN00007146': 128,
#  'ASN00007147': 128,
#  'ASN00007148': 128,
#  'ASN00007149': 128,
#  'ASN00007150': 128,
#  'ASN00007151': 44,
#  'ASN00007152': 128,
#  'ASN00007153': 128,
#  'ASN00007154': 128,
#  'ASN00007155': 128,
#  'ASN00007156': 128,
#  'ASN00007157': 128,
#  'ASN00007158': 128,
#  'ASN00007159': 128,
#  'ASN00007160': 128,
#  'ASN00007161': 44,
#  'ASN00007162': 128,
#  'ASN00007164': 128,
#  'ASN00007165': 128,
#  'ASN00007166': 128,
#  'ASN00007167': 128,
#  'ASN00007168': 41,
#  'ASN00007169': 128,
#  'ASN00007170': 128,
#  'ASN00007171': 128,
#  'ASN00007172': 128,
#  'ASN00007173': 128,
#  'ASN00007174': 128,
#  'ASN00007175': 128,
#  'ASN00007176': 44,
#  'ASN00007177': 128,
#  'ASN00007178': 44,
#  'ASN00007179': 128,
#  'ASN00007180': 128,
#  'ASN00007181': 128,
#  'ASN00007184': 128,
#  'ASN00007185': 44,
#  'ASN00007186': 128,
#  'ASN00007187': 128,
#  'ASN00007190': 128,
#  'ASN00007191': 128,
#  'ASN00007192': 128,
#  'ASN00007193': 128,
#  'ASN00007194': 128,
#  'ASN00007195': 128,
#  'ASN00007196': 128,
#  'ASN00007197': 128,
#  'ASN00007198': 128,
#  'ASN00007199': 128,
#  'ASN00007200': 128,
#  'ASN00007201': 128,
#  'ASN00007202': 128,
#  'ASN00007204': 44,
#  'ASN00007205': 44,
#  'ASN00007300': 128,
#  'ASN00007500': 128,
#  'ASN00007600': 44,
#  'ASN00008000': 128,
#  'ASN00008001': 128,
#  'ASN00008002': 128,
#  'ASN00008003': 128,
#  'ASN00008004': 128,
#  'ASN00008005': 128,
#  'ASN00008006': 128,
#  'ASN00008007': 128,
#  'ASN00008008': 128,
#  'ASN00008009': 128,
#  'ASN00008010': 128,
#  'ASN00008011': 128,
#  'ASN00008012': 128,
#  'ASN00008013': 128,
#  'ASN00008014': 128,
#  'ASN00008015': 128,
#  'ASN00008016': 128,
#  'ASN00008017': 128,
#  'ASN00008018': 128,
#  'ASN00008019': 128,
#  'ASN00008020': 128,
#  'ASN00008021': 128,
#  'ASN00008022': 128,
#  'ASN00008023': 128,
#  'ASN00008024': 128,
#  'ASN00008025': 41,
#  'ASN00008026': 128,
#  'ASN00008027': 128,
#  'ASN00008028': 41,
#  'ASN00008029': 128,
#  'ASN00008030': 128,
#  'ASN00008031': 128,
#  'ASN00008032': 128,
#  'ASN00008033': 128,
#  'ASN00008034': 128,
#  'ASN00008035': 128,
#  'ASN00008036': 128,
#  'ASN00008037': 128,
#  'ASN00008038': 128,
#  'ASN00008039': 41,
#  'ASN00008040': 128,
#  'ASN00008041': 128,
#  'ASN00008042': 128,
#  'ASN00008043': 128,
#  'ASN00008044': 128,
#  'ASN00008045': 128,
#  'ASN00008046': 128,
#  'ASN00008047': 128,
#  'ASN00008048': 128,
#  'ASN00008049': 128,
#  'ASN00008050': 41,
#  'ASN00008051': 41,
#  'ASN00008052': 128,
#  'ASN00008053': 128,
#  'ASN00008054': 128,
#  'ASN00008055': 128,
#  'ASN00008056': 128,
#  'ASN00008057': 128,
#  'ASN00008058': 128,
#  'ASN00008059': 128,
#  'ASN00008060': 128,
#  'ASN00008061': 128,
#  'ASN00008062': 128,
#  'ASN00008063': 128,
#  'ASN00008064': 128,
#  'ASN00008065': 128,
#  'ASN00008066': 128,
#  'ASN00008067': 128,
#  'ASN00008068': 128,
#  'ASN00008069': 128,
#  'ASN00008070': 128,
#  'ASN00008071': 128,
#  'ASN00008072': 128,
#  'ASN00008073': 128,
#  'ASN00008074': 128,
#  'ASN00008075': 128,
#  'ASN00008076': 128,
#  'ASN00008077': 128,
#  'ASN00008078': 128,
#  'ASN00008079': 128,
#  'ASN00008080': 128,
#  'ASN00008081': 128,
#  'ASN00008082': 128,
#  'ASN00008083': 128,
#  'ASN00008084': 128,
#  'ASN00008085': 128,
#  'ASN00008086': 128,
#  'ASN00008087': 128,
#  'ASN00008088': 41,
#  'ASN00008089': 128,
#  'ASN00008090': 128,
#  'ASN00008091': 41,
#  'ASN00008092': 128,
#  'ASN00008093': 41,
#  'ASN00008094': 128,
#  'ASN00008095': 41,
#  'ASN00008096': 128,
#  'ASN00008097': 128,
#  'ASN00008098': 128,
#  'ASN00008099': 128,
#  'ASN00008100': 128,
#  'ASN00008101': 128,
#  'ASN00008102': 128,
#  'ASN00008103': 128,
#  'ASN00008104': 128,
#  'ASN00008105': 128,
#  'ASN00008106': 128,
#  'ASN00008107': 128,
#  'ASN00008108': 128,
#  'ASN00008109': 128,
#  'ASN00008110': 128,
#  'ASN00008111': 128,
#  'ASN00008112': 128,
#  'ASN00008113': 128,
#  ...}

# %%
pickle.dump(new_Dict, open('stations_new_dictionary.pkl', 'w'))

# %% [markdown]
# Then use the new area dictionary to run PCA.

# %%
# %%writefile mr_weather_PCA_merge.py
#import collections
#Codes = collections.defaultdict(lambda: -1,Codes)
import sys
import cPickle
Dict = cPickle.load( open( "stations_new_dictionary.pkl", "rb" ) )
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re,pickle,base64,zlib
from sys import stderr
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

def my_pca(X,n):
    pca = PCA(n_components=n, whiten=True)
    pca.fit(X)
    sum1 = 0
    for i in range(n):
        sum1 = sum1 + pca.explained_variance_ratio_[i]
        if sum1 > 0.99:
            break
    return i,pca.components_

class MR_Weather_pca(MRJob):
    def my_mapper1(self, _, line):
        self.increment_counter('MrJob Counters','my_mapper1',1)
        elements=line.split(',')
        if elements[1]=='TMAX' or elements[1]=='TMIN':
            ndays = sum([e!='' for e in elements[3:]])
            measure = 1
            yield (elements[0],elements[2]), (measure,ndays,elements[3:])
            
    def my_reducer1(self, key, measures):
        self.increment_counter('MrJob Counters','my_reducer1',1)
        sum1 = 0; sum2 = 0; min_max = []
        for nmeasure,ndays,measure in measures:
            sum1 = sum1 + nmeasure; sum2 = sum2 + ndays; min_max = min_max + measure
        if sum1 == 2 and sum2>150:
            yield key, (Dict[key[0]],min_max)
            
    def my_mapper2(self, key, measures):
        self.increment_counter('MrJob Counters','my_mapper2',1)
        value = []
        for i in measures[1]:
            if i == '':
                value.append(np.nan)
            else:
                value.append(float(i))
        filled = pd.Series(value);filled = filled.interpolate();filled = filled.fillna(filled.mean())
        yield measures[0], list(filled)
    
    def my_reducer2(self, area, measures):
        self.increment_counter('MrJob Counters','my_reducer2',1)
        data = list(measures)
        data = np.array(data)
        n,eigenvectors = my_pca(data, data.shape[1])
        yield area, (data.shape[0],n)
    def steps(self):
        return [self.mr(mapper=self.my_mapper1, reducer=self.my_reducer1),
                self.mr(mapper=self.my_mapper2,reducer=self.my_reducer2)]
if __name__ == '__main__':
    MR_Weather_pca.run()
# Out:
# Overwriting mr_weather_PCA_merge.py

# %%
# !python mr_weather_PCA_merge.py -r emr --emr-job-flow-id $job_flow_id --file stations_new_dictionary.pkl hdfs:/Weather.GHNC/ALL.csv > PCA_merged_results
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating new scratch bucket mrjob-1fc94ecbbe4b701e
# using s3://mrjob-1fc94ecbbe4b701e/tmp/ as our scratch dir on S3
# creating tmp directory /tmp/mr_weather_PCA_merge.ubuntu.20140603.180859.459701
# creating S3 bucket 'mrjob-1fc94ecbbe4b701e' to use as scratch space
# Copying non-input files into s3://mrjob-1fc94ecbbe4b701e/tmp/mr_weather_PCA_merge.ubuntu.20140603.180859.459701/files/
# Adding our job to existing job flow j-3FZLTQVTVEUMJ
# Job launched 30.3s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 1 of 2)
# Job launched 60.6s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 1 of 2)
# Job launched 90.9s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 1 of 2)
# Job launched 121.3s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 1 of 2)
# Job launched 151.6s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 1 of 2)
# Job launched 181.9s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 1 of 2)
# Job launched 212.2s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 1 of 2)
# Job launched 242.5s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 1 of 2)
# Job launched 272.7s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 303.0s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 333.3s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 363.6s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 393.9s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 424.2s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 454.4s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 484.7s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 515.0s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 545.3s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 575.6s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 605.9s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 636.2s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 666.5s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 696.8s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 727.1s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 757.4s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 787.7s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job launched 818.0s ago, status RUNNING: Running step (mr_weather_PCA_merge.ubuntu.20140603.180859.459701: Step 2 of 2)
# Job completed.
# Running time was 815.0s (not counting time spent waiting for the EC2 instances)
# ec2_key_pair_file not specified, going to S3
# Fetching counters from S3...
# Waiting 5.0s for S3 eventual consistency
# Counters may not have been uploaded to S3 yet. Try again in 5 minutes with: mrjob fetch-logs --counters j-3FZLTQVTVEUMJ
# Counters from step 1:
#   (no counters found)
# Counters from step 2:
#   (no counters found)
# Streaming final output from s3://mrjob-1fc94ecbbe4b701e/tmp/mr_weather_PCA_merge.ubuntu.20140603.180859.459701/output/
# removing tmp directory /tmp/mr_weather_PCA_merge.ubuntu.20140603.180859.459701
# Removing all files in s3://mrjob-1fc94ecbbe4b701e/tmp/mr_weather_PCA_merge.ubuntu.20140603.180859.459701/

# %%
length_merge = []; area_merge=[]; k_merge = []
for line in open('PCA_merged_results','r').readlines():
    line=line.replace('[','')
    line=line.replace(']','')
    line=line.replace(',','')
    line=line.split()
    k_merge.append(numpy.int(line[1]))
    length_merge.append(numpy.int(line[2]))
    temp_area = numpy.float(line[0])
    area_merge.append(int(temp_area))
print mean(length_merge)
# Out:
# 462.890625

# %% [markdown]
# Now we have the descript length of PCA before and after merge. Then use the criterion described in  http://seed.ucsd.edu/mediawiki/index.php/BigDataHW2#Suggested_Steps to see whether each merge should or shoulndn't happen.

# %%
def merge_criterion(n1,k1,n2,k2,k3):
    n3 = n1+n2
    left = n1*k1+(k1+1)*(2*365)+n2*k2+(k2+1)*(2*365)
    right = n3*k3+(k3+1)*(2*365)
    merge = left>right
    return merge

# %%
before_merge = numpy.asarray([area, k, length])
after_merge = numpy.asarray([area_merge, k_merge, length_merge])
before_merge =  before_merge[:,np.argsort(before_merge[0,:])].transpose()
after_merge =  after_merge[:,np.argsort(after_merge[0,:])].transpose()

# %%
after_merge.shape
# Out:
# (128, 3)

# %%
merge = []
n = 365*2
for i in xrange(after_merge.shape[0]):
    temp = merge_criterion(n, before_merge[i*2,1], n, before_merge[i*2+1,1], after_merge[i,1])
    merge.append(temp)

# %%
merge
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
before_merge
# Out:
# array([[   0, 3546,  351],
#        [   1, 3591,  254],
#        [   2, 3655,  345],
#        [   3, 3689,  327],
#        [   4, 3679,  346],
#        [   5, 3650,  382],
#        [   6, 3639,  345],
#        [   7, 3659,  406],
#        [   8, 3693,  378],
#        [   9, 3655,  328],
#        [  10, 3621,  395],
#        [  11, 3651,  343],
#        [  12, 3653,  316],
#        [  13, 3577,  414],
#        [  14, 3693,  382],
#        [  15, 3611,  421],
#        [  16, 3663,  387],
#        [  17, 3648,  406],
#        [  18, 3654,  421],
#        [  19, 3671,  413],
#        [  20, 3647,  407],
#        [  21, 3689,  392],
#        [  22, 3678,  410],
#        [  23, 3680,  401],
#        [  24, 3668,  425],
#        [  25, 3673,  415],
#        [  26, 3709,  426],
#        [  27, 3655,  429],
#        [  28, 3626,  409],
#        [  29, 3725,  410],
#        [  30, 3635,  431],
#        [  31, 3664,  432],
#        [  32, 3723,  403],
#        [  33, 3647,  304],
#        [  34, 3681,  412],
#        [  35, 3610,  368],
#        [  36, 3669,  341],
#        [  37, 3625,  376],
#        [  38, 3657,  388],
#        [  39, 3649,  384],
#        [  40, 3664,  187],
#        [  41, 3643,  402],
#        [  42, 3644,  377],
#        [  43, 3636,  413],
#        [  44, 3686,  404],
#        [  45, 3656,  365],
#        [  46, 3614,  411],
#        [  47, 3641,  416],
#        [  48, 3678,  428],
#        [  49, 3645,  438],
#        [  50, 3664,  433],
#        [  51, 3681,  437],
#        [  52, 3702,  428],
#        [  53, 3644,  440],
#        [  54, 3682,  434],
#        [  55, 3662,  448],
#        [  56, 3624,  428],
#        [  57, 3656,  438],
#        [  58, 3618,  441],
#        [  59, 3663,  446],
#        [  60, 3590,  433],
#        [  61, 3655,  440],
#        [  62, 3670,  437],
#        [  63, 3668,  433],
#        [  64, 3563,  278],
#        [  65, 3585,  347],
#        [  66, 3712,  386],
#        [  67, 3590,  404],
#        [  68, 2725,  193],
#        [  69, 3124,  275],
#        [  70, 3619,  297],
#        [  71, 3384,  252],
#        [  72, 3747,  409],
#        [  73, 3607,  351],
#        [  74, 3583,  407],
#        [  75, 3659,  409],
#        [  76, 3593,  403],
#        [  77, 3635,  420],
#        [  78, 3602,  415],
#        [  79, 3643,  347],
#        [  80, 3737,  424],
#        [  81, 3711,  437],
#        [  82, 3724,  405],
#        [  83, 3705,  472],
#        [  84, 3712,  456],
#        [  85, 3691,  443],
#        [  86, 3730,  400],
#        [  87, 3706,  421],
#        [  88, 3621,  316],
#        [  89, 3667,  353],
#        [  90, 3526,  221],
#        [  91, 3644,  427],
#        [  92, 3735,  391],
#        [  93, 3713,  388],
#        [  94, 3600,  220],
#        [  95, 3574,  341],
#        [  96, 3620,  421],
#        [  97, 3700,  424],
#        [  98, 3682,  433],
#        [  99, 3644,  437],
#        [ 100, 3780,  429],
#        [ 101, 3595,  421],
#        [ 102, 3622,  439],
#        [ 103, 3600,  461],
#        [ 104, 3647,  428],
#        [ 105, 3679,  428],
#        [ 106, 3686,  436],
#        [ 107, 3648,  430],
#        [ 108, 3641,  149],
#        [ 109, 3653,  448],
#        [ 110, 3706,  433],
#        [ 111, 3671,  450],
#        [ 112, 3677,  431],
#        [ 113, 3639,  443],
#        [ 114, 3664,  466],
#        [ 115, 3639,  455],
#        [ 116, 3588,  441],
#        [ 117, 3646,  432],
#        [ 118, 3724,  465],
#        [ 119, 3297,  417],
#        [ 120, 3641,  475],
#        [ 121, 3662,  433],
#        [ 122, 3667,  482],
#        [ 123, 3620,  458],
#        [ 124, 3677,  471],
#        [ 125, 3192,  410],
#        [ 126, 3647,  459],
#        [ 127, 3308,  461],
#        [ 128, 3669,  392],
#        [ 129, 3639,  397],
#        [ 130, 3664,  414],
#        [ 131, 3640,  411],
#        [ 132, 3667,  427],
#        [ 133, 3677,  413],
#        [ 134, 3650,  405],
#        [ 135, 3675,  435],
#        [ 136, 3700,  393],
#        [ 137, 3643,  437],
#        [ 138, 3633,  462],
#        [ 139, 3684,  441],
#        [ 140, 3674,  428],
#        [ 141, 3644,  423],
#        [ 142, 3717,  434],
#        [ 143, 3599,  436],
#        [ 144, 3635,  461],
#        [ 145, 3642,  471],
#        [ 146, 3643,  453],
#        [ 147, 3658,  475],
#        [ 148, 3692,  440],
#        [ 149, 3670,  417],
#        [ 150, 3770,  449],
#        [ 151, 3720,  449],
#        [ 152, 3631,  464],
#        [ 153, 3707,  471],
#        [ 154, 3617,  453],
#        [ 155, 3725,  361],
#        [ 156, 3721,  470],
#        [ 157, 3628,  452],
#        [ 158, 3639,  479],
#        [ 159, 3697,  484],
#        [ 160, 3638,  452],
#        [ 161, 3718,  446],
#        [ 162, 3652,  491],
#        [ 163, 3666,  432],
#        [ 164, 3679,  418],
#        [ 165, 3667,  437],
#        [ 166, 3745,  428],
#        [ 167, 3626,  432],
#        [ 168, 3575,  457],
#        [ 169, 3607,  459],
#        [ 170, 3604,  439],
#        [ 171, 3525,  402],
#        [ 172, 3681,  460],
#        [ 173, 3568,  458],
#        [ 174, 3603,  386],
#        [ 175, 3586,  450],
#        [ 176, 3734,  456],
#        [ 177, 3610,  457],
#        [ 178, 3732,  458],
#        [ 179, 3672,  461],
#        [ 180, 3695,  474],
#        [ 181, 3690,  480],
#        [ 182, 3666,  479],
#        [ 183, 3721,  484],
#        [ 184, 3594,  452],
#        [ 185, 3647,  447],
#        [ 186, 3613,  420],
#        [ 187, 3609,  452],
#        [ 188, 3663,  450],
#        [ 189, 3711,  461],
#        [ 190, 3660,  441],
#        [ 191, 3572,  463],
#        [ 192, 3637,  433],
#        [ 193, 3686,  475],
#        [ 194, 3659,  441],
#        [ 195, 3596,  481],
#        [ 196, 3609,  490],
#        [ 197, 3677,  473],
#        [ 198, 3661,  495],
#        [ 199, 3658,  490],
#        [ 200, 3645,  454],
#        [ 201, 3689,  505],
#        [ 202, 3678,  472],
#        [ 203, 3659,  517],
#        [ 204, 3718,  498],
#        [ 205, 3682,  496],
#        [ 206, 3661,  505],
#        [ 207, 3665,  481],
#        [ 208, 3697,  480],
#        [ 209, 3560,  478],
#        [ 210, 3616,  493],
#        [ 211, 3571,  465],
#        [ 212, 3594,  495],
#        [ 213, 3046,  256],
#        [ 214, 3647,  497],
#        [ 215, 3436,  466],
#        [ 216, 3638,  498],
#        [ 217, 3604,  502],
#        [ 218, 3709,  439],
#        [ 219, 3659,  491],
#        [ 220, 3686,  433],
#        [ 221, 3427,  450],
#        [ 222, 3574,  518],
#        [ 223, 3592,  391],
#        [ 224, 3686,  528],
#        [ 225, 3687,  474],
#        [ 226, 3635,  527],
#        [ 227, 3673,  501],
#        [ 228, 3641,  517],
#        [ 229, 3706,  492],
#        [ 230, 3631,  533],
#        [ 231, 3521,  499],
#        [ 232, 3682,  539],
#        [ 233, 3655,  471],
#        [ 234, 3669,  429],
#        [ 235, 3716,  503],
#        [ 236, 3791,  473],
#        [ 237, 3415,  487],
#        [ 238, 3724,  472],
#        [ 239, 3409,  468],
#        [ 240, 3041,  431],
#        [ 241, 3309,  436],
#        [ 242, 3343,  451],
#        [ 243, 3253,  467],
#        [ 244, 3537,  467],
#        [ 245, 3596,  452],
#        [ 246, 3595,  481],
#        [ 247, 3575,  447],
#        [ 248, 3353,  473],
#        [ 249, 3405,  475],
#        [ 250, 3356,  495],
#        [ 251, 3540,  478],
#        [ 252, 3479,  475],
#        [ 253, 3694,  483],
#        [ 254, 3739,  485],
#        [ 255, 3636,  459]])

# %%
after_merge
# Out:
# array([[   0, 7137,  314],
#        [   1, 7344,  368],
#        [   2, 7329,  395],
#        [   3, 7298,  418],
#        [   4, 7348,  376],
#        [   5, 7272,  399],
#        [   6, 7230,  407],
#        [   7, 7304,  442],
#        [   8, 7311,  421],
#        [   9, 7325,  443],
#        [  10, 7336,  434],
#        [  11, 7358,  439],
#        [  12, 7341,  454],
#        [  13, 7364,  463],
#        [  14, 7351,  442],
#        [  15, 7299,  466],
#        [  16, 7370,  380],
#        [  17, 7291,  419],
#        [  18, 7294,  394],
#        [  19, 7306,  433],
#        [  20, 7307,  310],
#        [  21, 7280,  434],
#        [  22, 7342,  433],
#        [  23, 7255,  455],
#        [  24, 7323,  463],
#        [  25, 7345,  472],
#        [  26, 7346,  473],
#        [  27, 7344,  481],
#        [  28, 7280,  474],
#        [  29, 7281,  487],
#        [  30, 7245,  483],
#        [  31, 7338,  481],
#        [  32, 7148,  350],
#        [  33, 7302,  424],
#        [  34, 5849,  262],
#        [  35, 7003,  301],
#        [  36, 7354,  413],
#        [  37, 7242,  441],
#        [  38, 7228,  439],
#        [  39, 7245,  408],
#        [  40, 7448,  474],
#        [  41, 7429,  489],
#        [  42, 7403,  485],
#        [  43, 7436,  452],
#        [  44, 7288,  352],
#        [  45, 7170,  328],
#        [  46, 7448,  423],
#        [  47, 7174,  265],
#        [  48, 7320,  453],
#        [  49, 7326,  469],
#        [  50, 7375,  456],
#        [  51, 7222,  479],
#        [  52, 7326,  466],
#        [  53, 7334,  472],
#        [  54, 7294,  252],
#        [  55, 7377,  479],
#        [  56, 7316,  466],
#        [  57, 7303,  492],
#        [  58, 7234,  484],
#        [  59, 7021,  477],
#        [  60, 7303,  495],
#        [  61, 7287,  510],
#        [  62, 6869,  488],
#        [  63, 6955,  502],
#        [  64, 7308,  436],
#        [  65, 7304,  462],
#        [  66, 7344,  464],
#        [  67, 7325,  461],
#        [  68, 7343,  462],
#        [  69, 7317,  489],
#        [  70, 7318,  471],
#        [  71, 7316,  481],
#        [  72, 7277,  503],
#        [  73, 7301,  504],
#        [  74, 7362,  476],
#        [  75, 7490,  491],
#        [  76, 7338,  508],
#        [  77, 7342,  448],
#        [  78, 7349,  507],
#        [  79, 7336,  524],
#        [  80, 7356,  488],
#        [  81, 7318,  500],
#        [  82, 7346,  471],
#        [  83, 7371,  470],
#        [  84, 7182,  493],
#        [  85, 7129,  455],
#        [  86, 7249,  495],
#        [  87, 7189,  455],
#        [  88, 7344,  501],
#        [  89, 7404,  498],
#        [  90, 7385,  522],
#        [  91, 7387,  522],
#        [  92, 7241,  488],
#        [  93, 7222,  474],
#        [  94, 7374,  502],
#        [  95, 7232,  489],
#        [  96, 7323,  504],
#        [  97, 7255,  509],
#        [  98, 7286,  521],
#        [  99, 7319,  535],
#        [ 100, 7334,  521],
#        [ 101, 7337,  533],
#        [ 102, 7400,  534],
#        [ 103, 7326,  531],
#        [ 104, 7257,  516],
#        [ 105, 7187,  518],
#        [ 106, 6640,  397],
#        [ 107, 7083,  505],
#        [ 108, 7242,  537],
#        [ 109, 7368,  511],
#        [ 110, 7113,  480],
#        [ 111, 7166,  497],
#        [ 112, 7373,  549],
#        [ 113, 7308,  554],
#        [ 114, 7347,  541],
#        [ 115, 7152,  541],
#        [ 116, 7337,  523],
#        [ 117, 7385,  378],
#        [ 118, 7206,  519],
#        [ 119, 7133,  511],
#        [ 120, 6350,  465],
#        [ 121, 6596,  492],
#        [ 122, 7133,  495],
#        [ 123, 7170,  497],
#        [ 124, 6758,  510],
#        [ 125, 6896,  507],
#        [ 126, 7173,  508],
#        [ 127, 7375,  502]])
